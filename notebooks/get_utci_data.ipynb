# %% [markdown]
# # Script to query Climate Data Store API

# %% [markdown]
# ## Environment Setup

# %%
from pathlib import Path
import pandas as pd
import cdsapi

# %% [markdown]
# ## Path Structure

# %%
raw_data_dir = Path("../data/raw")
utci_data_dir = raw_data_dir / "utci"
utci_data_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Query Parameters

# %%
coords = {
    # "MOZ": [-10, 29.8, -27.1, 41.2],
    # "ZWE": [-15.45, 25.05, -22.65, 33.21],
    # "LSO": [-28.42, 26.85, -30.78, 29.65],
    # "NAM": [-16.84, 11.72, -29.04, 25.28],
#     "ZMB": [-8.2, 21.98, -18.08, 33.70],
#     "UGA": [4.25, 29.55, -1.49, 35.04],
    "KEN": [5.1, 33.84, -4.74, 41.92],
}
years = list(range(2000, 2025))

# %% [markdown]
# ## API Parameters

# %%
dataset = "derived-utci-historical"
request = {
    "variable": [
        # "universal_thermal_climate_index",
        # "universal_thermal_climate_index_daily_statistics",
        "universal_thermal_climate_index_monthly_statistics",
        # "universal_thermal_climate_index_seasonal_statistics",
        # "universal_thermal_climate_index_yearly_statistics",
        # "tropical_nights_thermal_comfort_yearly_statistics",
        # "tropical_nights_thermal_comfort_monthly_statistics",
        # "tropical_nights_thermal_comfort_seasonal_statistics"
    ],
    "version": "1_1",
    "product_type": "consolidated_dataset",
    "month": [f"{m:02d}" for m in range(1, 13)],
    "day": [f"{d:02d}" for d in range(1, 32)],
    "data_format": "netcdf"
}

# %%
for country, country_bbox in coords.items():
    country_data_dir = utci_data_dir / country
    country_data_dir.mkdir(parents=True, exist_ok=True)
    for year in years:
        request["year"] = str(year)
        request["area"] = country_bbox  
        request["target"] = str((utci_data_dir / f"utci_{country}_{year}.nc").resolve())
        print(f"Downloading UTCI data for {country} in {year}...")
        client = cdsapi.Client()
        client.retrieve(dataset, request)
# Out:
# Downloading UTCI data for KEN in 2000...
# 2025-11-13 15:11:18,550 WARNING [2025-09-26T00:00:00] The download of tropical nights statistics has been temporarily suspended. We are currently investigating the source of some unexpected values in these fields. At this time, we are unable to provide a specific timeframe for resolving this issue.  We apologize for the inconvenience and appreciate your patience while we address this matter.
# 2025-11-13 15:11:18,551 INFO Request ID is f8d801a8-f1da-41d8-af7a-08acd815f16d
# 2025-11-13 15:11:18,616 INFO status has been updated to accepted
# 2025-11-13 15:11:27,055 INFO status has been updated to running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 print(f"Downloading UTCI data for {country} in {year}...")
#       9 client = cdsapi.Client()
# ---> 10 client.retrieve(dataset, request)
#
# File ~/miniforge3/envs/agile/lib/python3.13/site-packages/ecmwf/datastores/legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File ~/miniforge3/envs/agile/lib/python3.13/site-packages/ecmwf/datastores/client.py:414, in Client.submit_and_wait_on_results(self, collection_id, request)
#     398 def submit_and_wait_on_results(
#     399     self, collection_id: str, request: dict[str, Any]
#     400 ) -> datastores.Results:
#     401     """Submit a request and wait for the results to be ready.
#     402
#     403     Parameters
#    (...)    412     datastores.Results
#     413     """
# --> 414     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File ~/miniforge3/envs/agile/lib/python3.13/site-packages/ecmwf/datastores/processing.py:495, in Remote.get_results(self)
#     488 def get_results(self) -> Results:
#     489     """Retrieve results.
#     490
#     491     Returns
#     492     -------
#     493     datastores.Results
#     494     """
# --> 495     return self._make_results(wait=True)
#
# File ~/miniforge3/envs/agile/lib/python3.13/site-packages/ecmwf/datastores/processing.py:479, in Remote._make_results(self, wait)
#     477 def _make_results(self, wait: bool) -> Results:
#     478     if wait:
# --> 479         self._wait_on_results()
#     480     response = self._get_api_response("get")
#     481     try:
#
# File ~/miniforge3/envs/agile/lib/python3.13/site-packages/ecmwf/datastores/processing.py:459, in Remote._wait_on_results(self)
#     457 while not self.results_ready:
#     458     self.debug(f"results not ready, waiting for {sleep} seconds")
# --> 459     time.sleep(sleep)
#     460     sleep = min(sleep * 1.5, self.sleep_max)
#
# KeyboardInterrupt:
