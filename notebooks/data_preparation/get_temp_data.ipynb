# %% [markdown]
# # Script to query Climate Data Store API

# %% [markdown]
# ## Environment Setup

# %%
from pathlib import Path
import pandas as pd
import cdsapi

# %% [markdown]
# ## Path Structure

# %%
raw_data_dir = Path("../../data/raw")
temp_data_dir = raw_data_dir / "temp_2m"
temp_data_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Query Parameters

# %%
coords = {
    # "MOZ": [-10, 29.8, -27.1, 41.2],
    # "ZWE": [-15.45, 25.05, -22.65, 33.21],
    # "LSO": [-28.42, 26.85, -30.78, 29.65],
    # "NAM": [-16.84, 11.72, -29.04, 25.28],
#     "ZMB": [-8.2, 21.98, -18.08, 33.70],
    "UGA": [4.25, 29.55, -1.49, 35.04],
    # "KEN": [5.1, 33.84, -4.74, 41.92],
}
years = list(range(2020, 2026))

# %% [markdown]
# ## API Parameters

# %%
dataset = "derived-era5-land-daily-statistics"
request = {
    "variable": [
        "2m_temperature",
    ],
    "daily_statistic": "daily_maximum",
    "month": [f"{m:02d}" for m in range(1, 13)],
    "day": [f"{d:02d}" for d in range(1, 32)],
    "frequency": "1_hourly",
    "time_zone": "utc+02:00",
    "data_format": "netcdf"
}

# %%
for country, country_bbox in coords.items():
    country_data_dir = temp_data_dir / country
    country_data_dir.mkdir(parents=True, exist_ok=True)
    for year in years:
        request["year"] = str(year)
        request["area"] = country_bbox 
        output_path = str((country_data_dir / f"t2m_{country}_{year}.nc").resolve())
        print(f"Downloading temperature data for {country} in {year}...")
        client = cdsapi.Client()
        client.retrieve(dataset, request, output_path)
# Out:
# Downloading temperature data for UGA in 2025...
# 2026-03-04 17:57:18,304 INFO Request ID is 52e11615-56ba-413e-89da-4dd6c094a128
# 2026-03-04 17:57:18,374 INFO status has been updated to accepted
# 2026-03-04 17:58:08,343 INFO status has been updated to running
# 2026-03-04 18:15:39,590 INFO status has been updated to successful
# a88fe73ed83342e9f8ebbed53c03a433.nc:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
